# %% [markdown]
# <a href="https://colab.research.google.com/github/polinm786/Artificial_Intelligence_Lab_03/blob/main/Copy_of_Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
courses = []
choice = 'random'

def line():
    print('---------------------------------------------')

def show_menu():
    line()
    print('Options')
    line()
    print('1. Add new course')
    print('2. Remove a course')
    print('3. View all courses')
    print('4. Exit')
    line()
    choice = input('Enter your choice: ')
    return choice

while choice!= '4':
    choice = show_menu()
    if choice == '1':
        item = input('Course Name: ')
        courses.append(item)
        print('Course ',item,' added')
    elif choice =='2':
        item = input('Which course do you want to remove or unroll? ')
        if item in courses:
            courses.remove(item)
            print('Unrolled from ',item,' course')
        else:
            print('You are not enrolled in this course')
    elif choice == '3':
        print('List of all enrolled courses:')
        for item in courses:
            print(item)
    elif choice == '4':
        print('Bye')
    else:
        print('Please enter one of 1,2,3 or 4')
# Out:
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 1
# Course Name: Artificial Intelligence
# Course  Artificial Intelligence  added
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 1
# Course Name: Database Management
# Course  Database Management  added
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 1
# Course Name: Software Project
# Course  Software Project  added
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 1
# Course Name: computer network
# Course  computer network  added
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 3
# List of all enrolled courses:
# Artificial Intelligence
# Database Management
# Software Project
# computer network
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 2
# Which course do you want to remove or unroll? computer network
# Unrolled from  computer network  course
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 3
# List of all enrolled courses:
# Artificial Intelligence
# Database Management
# Software Project
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 4
# Bye
